# %%
# !pip install xlrd==1.2.0

# %%
import xlrd

# %%
data=xlrd.open_workbook(filename=r'C:\Users\apple\Desktop\jupyter\Trade dealer\Trade\Paraguay with\Paraguay with -- (w,r,n).xlsx')

# %%
data

# %%
table1=data.sheets()[0]

# %%
table1

# %%
names=data.sheet_names()
names
# Out:
# ['Paraguay with -- (w,r,n)']

# %%
import json
import urllib.request
from random import randint
import time
import os
 
USER_AGENTS = [
    "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; AcooBrowser; .NET CLR 1.1.4322; .NET CLR 2.0.50727)",
    "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; Acoo Browser; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.0.04506)",
    "Mozilla/4.0 (compatible; MSIE 7.0; AOL 9.5; AOLBuild 4337.35; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727)",
    "Mozilla/5.0 (Windows; U; MSIE 9.0; Windows NT 9.0; en-US)",
    "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Win64; x64; Trident/5.0; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 2.0.50727; Media Center PC 6.0)",
    "Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 1.0.3705; .NET CLR 1.1.4322)",
    "Mozilla/4.0 (compatible; MSIE 7.0b; Windows NT 5.2; .NET CLR 1.1.4322; .NET CLR 2.0.50727; InfoPath.2; .NET CLR 3.0.04506.30)",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN) AppleWebKit/523.15 (KHTML, like Gecko, Safari/419.3) Arora/0.3 (Change: 287 c9dfb30)",
    "Mozilla/5.0 (X11; U; Linux; en-US) AppleWebKit/527+ (KHTML, like Gecko, Safari/419.3) Arora/0.6",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.8.1.2pre) Gecko/20070215 K-Ninja/2.1.1",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN; rv:1.9) Gecko/20080705 Firefox/3.0 Kapiko/3.0",
    "Mozilla/5.0 (X11; Linux i686; U;) Gecko/20070322 Kazehakase/0.4.5",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.8) Gecko Fedora/1.9.0.8-1.fc10 Kazehakase/0.5.6",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.56 Safari/535.11",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3) AppleWebKit/535.20 (KHTML, like Gecko) Chrome/19.0.1036.7 Safari/535.20",
    "Opera/9.80 (Macintosh; Intel Mac OS X 10.6.8; U; fr) Presto/2.9.168 Version/11.52",
    ]
 
def download_url(url, path, header):
    content = urllib.request.Request(url, headers=header)
    with urllib.request.urlopen(content) as file:
        with open(path,'wb') as outfile:
            outfile.write(file.read())
 
def main():
    random_agent = USER_AGENTS[randint(0, len(USER_AGENTS)-1)]
    header = {'User-Agent':random_agent}
    new_id = [156,251,276,344,360,381,392,446,104,528,554,408,608,702,710,410,724,752,764,826,842] #国家编码号
    #new_text = ["China","France","Germany","China, Hong Kong SAR","Indonesia","Italy","Japan","China, Macao SAR","Myanmar","Netherlands","New Zealand","Dem. People's Rep. of Korea","Philippines","Singapore","South Africa","Rep. of Korea","Spain","Sweden","Thailand","United Kingdom","USA"] #存放国家名称
    new_text = ["CHN","FRA","DEU","HKG","IDN","ITA","JPN","MAC","MMR","NLD","NZL","PRK","PHL","SGP","ZAF","KOR","ESP","SWE","THA","GBR","USA"]
    #------------------------------------------------------------------
    
    # 运行中断，继续下载需要更改下面参数
    begin_id =11 #当前年份已下载文件数目
    
    # 创建data文件夹存放下载数据
    year=1991
    if not os.path.exists("./data"):
        os.makedirs("./data")
    if not os.path.exists("./data/" + str(year)):
        os.makedirs("./data/" + str(year))
        
    for i in range(begin_id,begin_id+1):
        if not os.path.exists("./data/" + str(new_text[i])):
            os.makedirs("./data/" + str(year) + "/" + str(new_text[i]))
        for j in range(begin_id+1, len(new_id)):
            random_agent = USER_AGENTS[randint(0, len(USER_AGENTS)-1)]
            print(random_agent)
            header = {'User-Agent':random_agent}
            #url = "http://comtrade.un.org/api/get?max=100000&r=156&freq=A&ps=1991&px=ST&p=251,276,344,360,381,392,446,104,528,554,608,702,710,410,724,752,764,826,842&rg=1,2&cc=AG4&fmt=csv&type=C"
            url = "http://comtrade.un.org/api/get?max=100000&r=" + str(new_id[i]) + "&freq=A&ps=" + str(year) + "&px=ST&p="+str(new_id[j])+"&rg=1,2&cc=AG4&fmt=csv&type=C"
            path = "./data/" + str(year) + "/" + new_text[i]+"/"+str(new_text[j])+".csv"
            print("Downing from " + url + " to " + path)
            download_url(url,path,header)
            print("Done")
            # 暂停36秒，保证一小时访问100次
        time.sleep(36)

if __name__ == '__main__':
    main()
# Out:
# Mozilla/5.0 (Windows; U; MSIE 9.0; Windows NT 9.0; en-US)
# Downing from http://comtrade.un.org/api/get?max=100000&r=381&freq=A&ps=1991&px=ST&p=392&rg=1,2&cc=AG4&fmt=csv&type=C to ./data/1991/ITA/JPN.csv
# Done
# Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN) AppleWebKit/523.15 (KHTML, like Gecko, Safari/419.3) Arora/0.3 (Change: 287 c9dfb30)
# Downing from http://comtrade.un.org/api/get?max=100000&r=381&freq=A&ps=1991&px=ST&p=446&rg=1,2&cc=AG4&fmt=csv&type=C to ./data/1991/ITA/MAC.csv
# Done
# Opera/9.80 (Macintosh; Intel Mac OS X 10.6.8; U; fr) Presto/2.9.168 Version/11.52
# Downing from http://comtrade.un.org/api/get?max=100000&r=381&freq=A&ps=1991&px=ST&p=104&rg=1,2&cc=AG4&fmt=csv&type=C to ./data/1991/ITA/MMR.csv
# Done
# Mozilla/4.0 (compatible; MSIE 7.0b; Windows NT 5.2; .NET CLR 1.1.4322; .NET CLR 2.0.50727; InfoPath.2; .NET CLR 3.0.04506.30)
# ...

# %%
import json
import urllib.request
from random import randint
import time
import os
 
USER_AGENTS = [
    "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; AcooBrowser; .NET CLR 1.1.4322; .NET CLR 2.0.50727)",
    "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; Acoo Browser; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.0.04506)",
    "Mozilla/4.0 (compatible; MSIE 7.0; AOL 9.5; AOLBuild 4337.35; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727)",
    "Mozilla/5.0 (Windows; U; MSIE 9.0; Windows NT 9.0; en-US)",
    "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Win64; x64; Trident/5.0; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 2.0.50727; Media Center PC 6.0)",
    "Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 1.0.3705; .NET CLR 1.1.4322)",
    "Mozilla/4.0 (compatible; MSIE 7.0b; Windows NT 5.2; .NET CLR 1.1.4322; .NET CLR 2.0.50727; InfoPath.2; .NET CLR 3.0.04506.30)",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN) AppleWebKit/523.15 (KHTML, like Gecko, Safari/419.3) Arora/0.3 (Change: 287 c9dfb30)",
    "Mozilla/5.0 (X11; U; Linux; en-US) AppleWebKit/527+ (KHTML, like Gecko, Safari/419.3) Arora/0.6",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.8.1.2pre) Gecko/20070215 K-Ninja/2.1.1",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN; rv:1.9) Gecko/20080705 Firefox/3.0 Kapiko/3.0",
    "Mozilla/5.0 (X11; Linux i686; U;) Gecko/20070322 Kazehakase/0.4.5",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.8) Gecko Fedora/1.9.0.8-1.fc10 Kazehakase/0.5.6",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.56 Safari/535.11",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3) AppleWebKit/535.20 (KHTML, like Gecko) Chrome/19.0.1036.7 Safari/535.20",
    "Opera/9.80 (Macintosh; Intel Mac OS X 10.6.8; U; fr) Presto/2.9.168 Version/11.52",
    ]
 
def download_url(url, path, header):
    content = urllib.request.Request(url, headers=header)
    with urllib.request.urlopen(content) as file:
        with open(path,'wb') as outfile:
            outfile.write(file.read())
 
def main():
    random_agent = USER_AGENTS[randint(0, len(USER_AGENTS)-1)]
    header = {'User-Agent':random_agent}
    new_id = [156,251,276,344,360,381,392,446,104,528,554,408,608,702,710,410,724,752,764,826,842] #国家编码号
    #new_text = ["China","France","Germany","China, Hong Kong SAR","Indonesia","Italy","Japan","China, Macao SAR","Myanmar","Netherlands","New Zealand","Dem. People's Rep. of Korea","Philippines","Singapore","South Africa","Rep. of Korea","Spain","Sweden","Thailand","United Kingdom","USA"] #存放国家名称
    new_text = ["CHN","FRA","DEU","HKG","IDN","ITA","JPN","MAC","MMR","NLD","NZL","PRK","PHL","SGP","ZAF","KOR","ESP","SWE","THA","GBR","USA"]
    #------------------------------------------------------------------
    
    # 运行中断，继续下载需要更改下面参数
    begin_id =12 #当前年份已下载文件数目
    
    # 创建data文件夹存放下载数据
    year=1991
    if not os.path.exists("./data"):
        os.makedirs("./data")
    if not os.path.exists("./data/" + str(year)):
        os.makedirs("./data/" + str(year))
        
    for i in range(begin_id,begin_id+1):
        if not os.path.exists("./data/" + str(new_text[i])):
            os.makedirs("./data/" + str(year) + "/" + str(new_text[i]))
        for j in range(begin_id+1, len(new_id)):
            random_agent = USER_AGENTS[randint(0, len(USER_AGENTS)-1)]
            print(random_agent)
            header = {'User-Agent':random_agent}
            #url = "http://comtrade.un.org/api/get?max=100000&r=156&freq=A&ps=1991&px=ST&p=251,276,344,360,381,392,446,104,528,554,608,702,710,410,724,752,764,826,842&rg=1,2&cc=AG4&fmt=csv&type=C"
            url = "http://comtrade.un.org/api/get?max=100000&r=" + str(new_id[i]) + "&freq=A&ps=" + str(year) + "&px=ST&p="+str(new_id[j])+"&rg=1,2&cc=AG4&fmt=csv&type=C"
            path = "./data/" + str(year) + "/" + new_text[i]+"/"+str(new_text[j])+".csv"
            print("Downing from " + url + " to " + path)
            download_url(url,path,header)
            print("Done")
            # 暂停36秒，保证一小时访问100次
        time.sleep(36)

 
if __name__ == '__main__':
    main()
# Out:
# Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; AcooBrowser; .NET CLR 1.1.4322; .NET CLR 2.0.50727)
# Downing from http://comtrade.un.org/api/get?max=100000&r=608&freq=A&ps=1991&px=ST&p=702&rg=1,2&cc=AG4&fmt=csv&type=C to ./data/1991/PHL/SGP.csv
# Done
# Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; AcooBrowser; .NET CLR 1.1.4322; .NET CLR 2.0.50727)
# Downing from http://comtrade.un.org/api/get?max=100000&r=608&freq=A&ps=1991&px=ST&p=710&rg=1,2&cc=AG4&fmt=csv&type=C to ./data/1991/PHL/ZAF.csv
# Done
# Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; Acoo Browser; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.0.04506)
# Downing from http://comtrade.un.org/api/get?max=100000&r=608&freq=A&ps=1991&px=ST&p=410&rg=1,2&cc=AG4&fmt=csv&type=C to ./data/1991/PHL/KOR.csv
# Done
# Mozilla/5.0 (Windows; U; MSIE 9.0; Windows NT 9.0; en-US)
# ...

# %%
import json
import urllib.request
from random import randint
import time
import os
 
USER_AGENTS = [
    "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; AcooBrowser; .NET CLR 1.1.4322; .NET CLR 2.0.50727)",
    "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; Acoo Browser; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.0.04506)",
    "Mozilla/4.0 (compatible; MSIE 7.0; AOL 9.5; AOLBuild 4337.35; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727)",
    "Mozilla/5.0 (Windows; U; MSIE 9.0; Windows NT 9.0; en-US)",
    "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Win64; x64; Trident/5.0; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 2.0.50727; Media Center PC 6.0)",
    "Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 1.0.3705; .NET CLR 1.1.4322)",
    "Mozilla/4.0 (compatible; MSIE 7.0b; Windows NT 5.2; .NET CLR 1.1.4322; .NET CLR 2.0.50727; InfoPath.2; .NET CLR 3.0.04506.30)",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN) AppleWebKit/523.15 (KHTML, like Gecko, Safari/419.3) Arora/0.3 (Change: 287 c9dfb30)",
    "Mozilla/5.0 (X11; U; Linux; en-US) AppleWebKit/527+ (KHTML, like Gecko, Safari/419.3) Arora/0.6",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.8.1.2pre) Gecko/20070215 K-Ninja/2.1.1",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN; rv:1.9) Gecko/20080705 Firefox/3.0 Kapiko/3.0",
    "Mozilla/5.0 (X11; Linux i686; U;) Gecko/20070322 Kazehakase/0.4.5",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.8) Gecko Fedora/1.9.0.8-1.fc10 Kazehakase/0.5.6",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.56 Safari/535.11",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3) AppleWebKit/535.20 (KHTML, like Gecko) Chrome/19.0.1036.7 Safari/535.20",
    "Opera/9.80 (Macintosh; Intel Mac OS X 10.6.8; U; fr) Presto/2.9.168 Version/11.52",
    ]
 
def download_url(url, path, header):
    content = urllib.request.Request(url, headers=header)
    with urllib.request.urlopen(content) as file:
        with open(path,'wb') as outfile:
            outfile.write(file.read())
 
def main():
    random_agent = USER_AGENTS[randint(0, len(USER_AGENTS)-1)]
    header = {'User-Agent':random_agent}
    new_id = [156,251,276,344,360,381,392,446,104,528,554,408,608,702,710,410,724,752,764,826,842] #国家编码号
    #new_text = ["China","France","Germany","China, Hong Kong SAR","Indonesia","Italy","Japan","China, Macao SAR","Myanmar","Netherlands","New Zealand","Dem. People's Rep. of Korea","Philippines","Singapore","South Africa","Rep. of Korea","Spain","Sweden","Thailand","United Kingdom","USA"] #存放国家名称
    new_text = ["CHN","FRA","DEU","HKG","IDN","ITA","JPN","MAC","MMR","NLD","NZL","PRK","PHL","SGP","ZAF","KOR","ESP","SWE","THA","GBR","USA"]
    #------------------------------------------------------------------
    
    begin_id =11 
    
    year=1991
    if not os.path.exists("./data"):
        os.makedirs("./data")
    if not os.path.exists("./data/" + str(year)):
        os.makedirs("./data/" + str(year))
        
    for i in range(begin_id,begin_id+1):
        if not os.path.exists("./data/" + str(new_text[i])):
            os.makedirs("./data/" + str(year) + "/" + str(new_text[i]))
        for j in range(begin_id+1, len(new_id)):
            random_agent = USER_AGENTS[randint(0, len(USER_AGENTS)-1)]
            print(random_agent)
            header = {'User-Agent':random_agent}
            #url = "http://comtrade.un.org/api/get?max=100000&r=156&freq=A&ps=1991&px=ST&p=251,276,344,360,381,392,446,104,528,554,608,702,710,410,724,752,764,826,842&rg=1,2&cc=AG4&fmt=csv&type=C"
            url = "http://comtrade.un.org/api/get?max=100000&r=" + str(new_id[i]) + "&freq=A&ps=" + str(year) + "&px=ST&p="+str(new_id[j])+"&rg=1,2&cc=AG4&fmt=csv&type=C"
            path = "./data/" + str(year) + "/" + new_text[i]+"/"+str(new_text[j])+".csv"
            print("Downing from " + url + " to " + path)
            download_url(url,path,header)
            print("Done")
        time.sleep(36)

if __name__ == '__main__':
    main()
